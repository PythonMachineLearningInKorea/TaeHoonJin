# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os as os
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
plt.style.use('seaborn')

# %%
train_df = pd.read_csv("C:/Users/HOME/Desktop/머신러닝/천체/train.csv")
test_df = pd.read_csv("C:/Users/HOME/Desktop/머신러닝/천체/test.csv")
submission = pd.read_csv("C:/Users/HOME/Desktop/머신러닝/천체/sample_submission.csv")
submission["type"] = "Unknown"

# %%
le = LabelEncoder()
train_df['type'] = le.fit_transform(train_df['type'])
print(train_df.type.value_counts())
# Out:
# 1     49680
# 0     37347
# 4     21760
# 10    14630
# 2     14618
# 16    13750
# 11    13500
# 6      7132
# 3      6580
# 14     6506
# 5      4654
# 13     3257
# 8      2562
# 18     2160
# 17     1154
# 12      500
# 9       127
# 7        61
# 15       13
# Name: type, dtype: int64

# %%
train_df.head()
# Out:
#    id  type  fiberID   psfMag_u   psfMag_g   psfMag_r   psfMag_i   psfMag_z  \
# 0   0     1      601  23.198224  21.431953  21.314148  21.176553  21.171444
# 1   1     1      788  21.431355  20.708104  20.678850  20.703420  20.473229
# 2   2     1      427  17.851451  16.727898  16.679677  16.694640  16.641788
# 3   3     1      864  20.789900  20.040371  19.926909  19.843840  19.463270
# 4   4    16      612  26.454969  23.058767  21.471406  19.504961  18.389096
#
#    fiberMag_u  fiberMag_g  ...  petroMag_u  petroMag_g  petroMag_r  \
# 0   22.581309   21.644453  ...   22.504317   21.431636   21.478312
# 1   21.868797   21.029773  ...   21.360701   20.778968   20.889705
# 2   18.171890   17.033098  ...   17.867253   16.738784   16.688874
# 3   21.039030   20.317165  ...   20.433907   19.993727   19.985531
# 4   25.700632   23.629122  ...   25.859229   22.426929   21.673551
#
#    petroMag_i  petroMag_z  modelMag_u  modelMag_g  modelMag_r  modelMag_i  \
# ...

# %%
train_data_x=train_df.drop(columns=['fiberID'])

# %%
train_data_x.head()
# Out:
#    id  type   psfMag_u   psfMag_g   psfMag_r   psfMag_i   psfMag_z  \
# 0   0     1  23.198224  21.431953  21.314148  21.176553  21.171444
# 1   1     1  21.431355  20.708104  20.678850  20.703420  20.473229
# 2   2     1  17.851451  16.727898  16.679677  16.694640  16.641788
# 3   3     1  20.789900  20.040371  19.926909  19.843840  19.463270
# 4   4    16  26.454969  23.058767  21.471406  19.504961  18.389096
#
#    fiberMag_u  fiberMag_g  fiberMag_r  ...  petroMag_u  petroMag_g  \
# 0   22.581309   21.644453   21.657571  ...   22.504317   21.431636
# 1   21.868797   21.029773   20.967054  ...   21.360701   20.778968
# 2   18.171890   17.033098   16.999682  ...   17.867253   16.738784
# 3   21.039030   20.317165   20.217898  ...   20.433907   19.993727
# 4   25.700632   23.629122   21.742750  ...   25.859229   22.426929
#
#    petroMag_r  petroMag_i  petroMag_z  modelMag_u  modelMag_g  modelMag_r  \
# 0   21.478312   21.145409   20.422446   22.749241   21.465534   21.364187
# ...

# %%
train_data_y=train_data['type']
train_data_x=train_data_x.drop(columns=['type'])

# %%
train_data_x.head()
# Out:
#    id   psfMag_u   psfMag_g   psfMag_r   psfMag_i   psfMag_z  fiberMag_u  \
# 0   0  23.198224  21.431953  21.314148  21.176553  21.171444   22.581309
# 1   1  21.431355  20.708104  20.678850  20.703420  20.473229   21.868797
# 2   2  17.851451  16.727898  16.679677  16.694640  16.641788   18.171890
# 3   3  20.789900  20.040371  19.926909  19.843840  19.463270   21.039030
# 4   4  26.454969  23.058767  21.471406  19.504961  18.389096   25.700632
#
#    fiberMag_g  fiberMag_r  fiberMag_i  ...  petroMag_u  petroMag_g  \
# 0   21.644453   21.657571   21.387653  ...   22.504317   21.431636
# 1   21.029773   20.967054   20.937731  ...   21.360701   20.778968
# 2   17.033098   16.999682   17.095999  ...   17.867253   16.738784
# 3   20.317165   20.217898   20.073852  ...   20.433907   19.993727
# 4   23.629122   21.742750   19.861718  ...   25.859229   22.426929
#
#    petroMag_r  petroMag_i  petroMag_z  modelMag_u  modelMag_g  modelMag_r  \
# ...

# %%
train_data_y
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4         16
#           ..
# 199986     1
# 199987     0
# 199988    16
# 199989     0
# 199990     1
# Name: type, Length: 199991, dtype: int64

# %%
train_data_x.describe()
## psfMag_u, fiberMag_u 가 평균이 낮음
# Out:
#                  id      psfMag_u       psfMag_g       psfMag_r  \
# count  199991.00000  1.999910e+05  199991.000000  199991.000000
# mean    99995.00000 -6.750146e+00      18.675373      18.401235
# std     57732.57318  1.187678e+04     155.423024     127.128078
# min         0.00000 -5.310802e+06  -40022.466071  -27184.795793
# 25%     49997.50000  1.965259e+01      18.701180      18.048572
# 50%     99995.00000  2.087136e+01      19.904235      19.454492
# 75%    149992.50000  2.216043e+01      21.150297      20.515936
# max    199990.00000  1.877392e+04    3538.984910    3048.110913
#
#             psfMag_i       psfMag_z    fiberMag_u     fiberMag_g  \
# count  199991.000000  199991.000000  1.999910e+05  199991.000000
# mean       18.043495      17.663526  1.084986e+01      19.072693
# std       116.622194     123.735298  4.172116e+03     749.256162
# min    -26566.310827  -24878.828280 -1.864766e+06 -215882.917191
# ...

# %%
train_data_x[train_data_x['psfMag_u'] < -100000]['psfMag_u']
# Out:
# 139197   -5.310802e+06
# Name: psfMag_u, dtype: float64

# %%
train_data_x[train_data_x['fiberMag_u']< -10000]['fiberMag_u']
# Out:
# 3991     -1.805492e+04
# 18277    -1.550113e+04
# 37735    -2.607040e+04
# 46441    -1.637564e+04
# 46896    -1.561192e+04
# 67227    -1.669734e+04
# 74089    -1.501157e+04
# 139197   -1.864766e+06
# 143592   -1.047190e+04
# 154235   -2.999408e+04
# 187706   -1.596599e+04
# Name: fiberMag_u, dtype: float64

# %%
train_data_x[train_data_x['psfMag_u'] < -100000]['psfMag_u']
# Out:
# -5.310802e+06    1
# Name: psfMag_u, dtype: int64

# %%
train_data_x[train_data_x['fiberMag_u']< -10000]['fiberMag_u']
# Out:
# -2.607040e+04    1
# -1.669734e+04    1
# -1.637564e+04    1
# -1.864766e+06    1
# -1.561192e+04    1
# -1.550113e+04    1
# -1.805492e+04    1
# -2.999408e+04    1
# -1.047190e+04    1
# -1.501157e+04    1
# -1.596599e+04    1
# Name: fiberMag_u, dtype: int64

# %%
train_data_x.drop(train_data_x[train_data_x['psfMag_u'] < -100000]['psfMag_u'].index,axis=0,inplace=True)

# %%
train_data_x.drop(train_data_x[train_data_x['fiberMag_u'] < -100000]['fiberMag_u'].index,axis=0,inplace=True)

# %%
train_data_x.describe()
# Out:
#             psfMag_u       psfMag_g       psfMag_r       psfMag_i  \
# count  199990.000000  199990.000000  199990.000000  199990.000000
# mean       19.805157      18.675359      18.401222      18.043479
# std       165.971614     155.423413     127.128396     116.622485
# min    -31887.480703  -40022.466071  -27184.795793  -26566.310827
# 25%        19.652600      18.701163      18.048561      17.747661
# 50%        20.871382      19.904232      19.454489      19.043885
# 75%        22.160438      21.150260      20.515926      20.073512
# max     18773.919070    3538.984910    3048.110913    4835.218639
#
#             psfMag_z     fiberMag_u     fiberMag_g     fiberMag_r  \
# count  199990.000000  199990.000000  199990.000000  199990.000000
# mean       17.663509      20.174211      19.072679      19.134470
# std       123.735607     136.486245     749.258035      90.049283
# min    -24878.828280  -29994.080332 -215882.917191  -21802.656144
# ...

# %%
train_id=train_df['id']
train_data = train_df.drop(columns=['id'],axis=1)

# %%
test_id=test_df['id']
test_df=test_df.drop(columns=['id'],axis=1)

# %%
rfclf = RandomForestClassifier(n_estimators=1000)
rfclf.fit(train_data_x,train_data_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-791cf29aa117> in <module>
#       1 rfclf = RandomForestClassifier(n_estimators=1000)
# ----> 2 rfclf.fit(train_data_x,train_data_y)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     328                     t, self, X, y, sample_weight, i, len(trees),
#     329                     verbose=self.verbose, class_weight=self.class_weight)
# --> 330                 for i, t in enumerate(trees))
#     331
#     332             # Collect newly grown trees
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     919             # remaining jobs.
#     920             self._iterating = False
# --> 921             if self.dispatch_one_batch(iterator):
#     922                 self._iterating = self._original_iterator is not None
#     923
#
# ...
